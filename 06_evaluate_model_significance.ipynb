# %%
#import relevant libraries
import os
import subprocess
import numpy as np
import pandas as pd
import sys; sys.path
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.multitest import multipletests as fdr

# %%
#set base directory and load in all prediciton accuracy (Pearson correlation) results files
base_dir  = '/Users/elvishadhamala/Documents/yale/HCP_ABCD_preds_results'

#sex-independent model results
surfarea_HCP = np.load(os.path.join(base_dir, 'surfarea_corr_HCP.npy'))
surfarea_ABCD = np.load(os.path.join(base_dir, 'surfarea_corr_ABCD.npy'))

grayvol_HCP = np.load(os.path.join(base_dir, 'grayvol_corr_HCP.npy'))
grayvol_ABCD = np.load(os.path.join(base_dir, 'grayvol_corr_ABCD.npy'))

thick_HCP = np.load(os.path.join(base_dir, 'thick_corr_HCP.npy'))
thick_ABCD = np.load(os.path.join(base_dir, 'thick_corr_ABCD.npy'))

surfarea_norm_HCP = np.load(os.path.join(base_dir, 'surfarea_norm_corr_HCP.npy'))
surfarea_norm_ABCD = np.load(os.path.join(base_dir, 'surfarea_norm_corr_ABCD.npy'))

grayvol_norm_HCP = np.load(os.path.join(base_dir, 'grayvol_norm_corr_HCP.npy'))
grayvol_norm_ABCD = np.load(os.path.join(base_dir, 'grayvol_norm_corr_ABCD.npy'))

thick_norm_HCP = np.load(os.path.join(base_dir, 'thick_norm_corr_HCP.npy'))
thick_norm_ABCD = np.load(os.path.join(base_dir, 'thick_norm_corr_ABCD.npy'))


#sex-specific model results
surfarea_HCP_m = np.load(os.path.join(base_dir, 'surfarea_corr_HCP_m.npy'))
surfarea_HCP_f = np.load(os.path.join(base_dir, 'surfarea_corr_HCP_f.npy'))
surfarea_ABCD_m = np.load(os.path.join(base_dir, 'surfarea_corr_ABCD_m.npy'))
surfarea_ABCD_f = np.load(os.path.join(base_dir, 'surfarea_corr_ABCD_f.npy'))

grayvol_HCP_m = np.load(os.path.join(base_dir, 'grayvol_corr_HCP_m.npy'))
grayvol_HCP_f = np.load(os.path.join(base_dir, 'grayvol_corr_HCP_f.npy'))
grayvol_ABCD_m = np.load(os.path.join(base_dir, 'grayvol_corr_ABCD_m.npy'))
grayvol_ABCD_f = np.load(os.path.join(base_dir, 'grayvol_corr_ABCD_f.npy'))

thick_HCP_m = np.load(os.path.join(base_dir, 'thick_corr_HCP_m.npy'))
thick_HCP_f = np.load(os.path.join(base_dir, 'thick_corr_HCP_f.npy'))
thick_ABCD_m = np.load(os.path.join(base_dir, 'thick_corr_ABCD_m.npy'))
thick_ABCD_f = np.load(os.path.join(base_dir, 'thick_corr_ABCD_f.npy'))


surfarea_norm_HCP_m = np.load(os.path.join(base_dir, 'surfarea_norm_corr_HCP_m.npy'))
surfarea_norm_HCP_f = np.load(os.path.join(base_dir, 'surfarea_norm_corr_HCP_f.npy'))
surfarea_norm_ABCD_m = np.load(os.path.join(base_dir, 'surfarea_norm_corr_ABCD_m.npy'))
surfarea_norm_ABCD_f = np.load(os.path.join(base_dir, 'surfarea_norm_corr_ABCD_f.npy'))

grayvol_norm_HCP_m = np.load(os.path.join(base_dir, 'grayvol_norm_corr_HCP_m.npy'))
grayvol_norm_HCP_f = np.load(os.path.join(base_dir, 'grayvol_norm_corr_HCP_f.npy'))
grayvol_norm_ABCD_m = np.load(os.path.join(base_dir, 'grayvol_norm_corr_ABCD_m.npy'))
grayvol_norm_ABCD_f = np.load(os.path.join(base_dir, 'grayvol_norm_corr_ABCD_f.npy'))

thick_norm_HCP_m = np.load(os.path.join(base_dir, 'thick_norm_corr_HCP_m.npy'))
thick_norm_HCP_f = np.load(os.path.join(base_dir, 'thick_norm_corr_HCP_f.npy'))
thick_norm_ABCD_m = np.load(os.path.join(base_dir, 'thick_norm_corr_ABCD_m.npy'))
thick_norm_ABCD_f = np.load(os.path.join(base_dir, 'thick_norm_corr_ABCD_f.npy'))

# %%
#sex-independent null model results
null_surfarea_HCP = np.load(os.path.join(base_dir, 'null_surfarea_corr_HCP.npy'))
null_surfarea_ABCD = np.load(os.path.join(base_dir, 'null_surfarea_corr_ABCD.npy'))

null_grayvol_HCP = np.load(os.path.join(base_dir, 'null_grayvol_corr_HCP.npy'))
null_grayvol_ABCD = np.load(os.path.join(base_dir, 'null_grayvol_corr_ABCD.npy'))

null_thick_HCP = np.load(os.path.join(base_dir, 'null_thick_corr_HCP.npy'))
null_thick_ABCD = np.load(os.path.join(base_dir, 'null_thick_corr_ABCD.npy'))

null_surfarea_norm_HCP = np.load(os.path.join(base_dir, 'null_surfarea_norm_corr_HCP.npy'))
null_surfarea_norm_ABCD = np.load(os.path.join(base_dir, 'null_surfarea_norm_corr_ABCD.npy'))

null_grayvol_norm_HCP = np.load(os.path.join(base_dir, 'null_grayvol_norm_corr_HCP.npy'))
null_grayvol_norm_ABCD = np.load(os.path.join(base_dir, 'null_grayvol_norm_corr_ABCD.npy'))

null_thick_norm_HCP = np.load(os.path.join(base_dir, 'null_thick_norm_corr_HCP.npy'))
null_thick_norm_ABCD = np.load(os.path.join(base_dir, 'null_thick_norm_corr_ABCD.npy'))


#sex-specific null model results
null_surfarea_HCP_m = np.load(os.path.join(base_dir, 'null_surfarea_corr_HCP_m.npy'))
null_surfarea_HCP_f = np.load(os.path.join(base_dir, 'null_surfarea_corr_HCP_f.npy'))
null_surfarea_ABCD_m = np.load(os.path.join(base_dir, 'null_surfarea_corr_ABCD_m.npy'))
null_surfarea_ABCD_f = np.load(os.path.join(base_dir, 'null_surfarea_corr_ABCD_f.npy'))

null_grayvol_HCP_m = np.load(os.path.join(base_dir, 'null_grayvol_corr_HCP_m.npy'))
null_grayvol_HCP_f = np.load(os.path.join(base_dir, 'null_grayvol_corr_HCP_f.npy'))
null_grayvol_ABCD_m = np.load(os.path.join(base_dir, 'null_grayvol_corr_ABCD_m.npy'))
null_grayvol_ABCD_f = np.load(os.path.join(base_dir, 'null_grayvol_corr_ABCD_f.npy'))

null_thick_HCP_m = np.load(os.path.join(base_dir, 'null_thick_corr_HCP_m.npy'))
null_thick_HCP_f = np.load(os.path.join(base_dir, 'null_thick_corr_HCP_f.npy'))
null_thick_ABCD_m = np.load(os.path.join(base_dir, 'null_thick_corr_ABCD_m.npy'))
null_thick_ABCD_f = np.load(os.path.join(base_dir, 'null_thick_corr_ABCD_f.npy'))


null_surfarea_norm_HCP_m = np.load(os.path.join(base_dir, 'null_surfarea_norm_corr_HCP_m.npy'))
null_surfarea_norm_HCP_f = np.load(os.path.join(base_dir, 'null_surfarea_norm_corr_HCP_f.npy'))
null_surfarea_norm_ABCD_m = np.load(os.path.join(base_dir, 'null_surfarea_norm_corr_ABCD_m.npy'))
null_surfarea_norm_ABCD_f = np.load(os.path.join(base_dir, 'null_surfarea_norm_corr_ABCD_f.npy'))

null_grayvol_norm_HCP_m = np.load(os.path.join(base_dir, 'null_grayvol_norm_corr_HCP_m.npy'))
null_grayvol_norm_HCP_f = np.load(os.path.join(base_dir, 'null_grayvol_norm_corr_HCP_f.npy'))
null_grayvol_norm_ABCD_m = np.load(os.path.join(base_dir, 'null_grayvol_norm_corr_ABCD_m.npy'))
null_grayvol_norm_ABCD_f = np.load(os.path.join(base_dir, 'null_grayvol_norm_corr_ABCD_f.npy'))

null_thick_norm_HCP_m = np.load(os.path.join(base_dir, 'null_thick_norm_corr_HCP_m.npy'))
null_thick_norm_HCP_f = np.load(os.path.join(base_dir, 'null_thick_norm_corr_HCP_f.npy'))
null_thick_norm_ABCD_m = np.load(os.path.join(base_dir, 'null_thick_norm_corr_ABCD_m.npy'))
null_thick_norm_ABCD_f = np.load(os.path.join(base_dir, 'null_thick_norm_corr_ABCD_f.npy'))

# %%
#function to compare performance between a pair of models 
def get_exact_p(x,y):
    pval = 2*np.min([np.mean(x-y>=0), np.mean(x-y<=0)])
    
    return pval

# %%
#function to compare perforance between a model and its null 
def get_null_p(x,null):
    pval = 1-np.mean(x-null>=0)
    
    return pval

# %%
#create variables to store p values once computed
n_cog = null_surfarea_HCP.shape[1]
test_si = null_surfarea_HCP.shape[2]
test_ss = null_surfarea_HCP_m.shape[2]


p_surfarea_HCP = np.zeros([n_cog, test_si])
p_grayvol_HCP = np.zeros([n_cog, test_si])
p_thick_HCP = np.zeros([n_cog, test_si])

p_surfarea_norm_HCP = np.zeros([n_cog, test_si])
p_grayvol_norm_HCP = np.zeros([n_cog, test_si])
p_thick_norm_HCP = np.zeros([n_cog, test_si])

p_surfarea_HCP_m = np.zeros([n_cog, test_ss])
p_grayvol_HCP_m = np.zeros([n_cog, test_ss])
p_thick_HCP_m = np.zeros([n_cog, test_ss])

p_surfarea_norm_HCP_m = np.zeros([n_cog, test_ss])
p_grayvol_norm_HCP_m = np.zeros([n_cog, test_ss])
p_thick_norm_HCP_m = np.zeros([n_cog, test_ss])

p_surfarea_HCP_f = np.zeros([n_cog, test_ss])
p_grayvol_HCP_f = np.zeros([n_cog, test_ss])
p_thick_HCP_f = np.zeros([n_cog, test_ss])

p_surfarea_norm_HCP_f = np.zeros([n_cog, test_ss])
p_grayvol_norm_HCP_f = np.zeros([n_cog, test_ss])
p_thick_norm_HCP_f = np.zeros([n_cog, test_ss])


p_surfarea_ABCD = np.zeros([n_cog, test_si])
p_grayvol_ABCD = np.zeros([n_cog, test_si])
p_thick_ABCD = np.zeros([n_cog, test_si])

p_surfarea_norm_ABCD = np.zeros([n_cog, test_si])
p_grayvol_norm_ABCD = np.zeros([n_cog, test_si])
p_thick_norm_ABCD = np.zeros([n_cog, test_si])

p_surfarea_ABCD_m = np.zeros([n_cog, test_ss])
p_grayvol_ABCD_m = np.zeros([n_cog, test_ss])
p_thick_ABCD_m = np.zeros([n_cog, test_ss])

p_surfarea_norm_ABCD_m = np.zeros([n_cog, test_ss])
p_grayvol_norm_ABCD_m = np.zeros([n_cog, test_ss])
p_thick_norm_ABCD_m = np.zeros([n_cog, test_ss])

p_surfarea_ABCD_f = np.zeros([n_cog, test_ss])
p_grayvol_ABCD_f = np.zeros([n_cog, test_ss])
p_thick_ABCD_f = np.zeros([n_cog, test_ss])

p_surfarea_norm_ABCD_f = np.zeros([n_cog, test_ss])
p_grayvol_norm_ABCD_f = np.zeros([n_cog, test_ss])
p_thick_norm_ABCD_f = np.zeros([n_cog, test_ss])


#get p values comparing true sex-independent models to null models
for i in range(n_cog):
    for j in range(test_si):
        p_surfarea_HCP[i,j] = get_null_p(surfarea_HCP[:,i,j], np.median(null_surfarea_HCP[:,i,j]))
        p_surfarea_ABCD[i,j] = get_null_p(surfarea_ABCD[:,i,j], np.median(null_surfarea_ABCD[:,i,j]))
        
        p_grayvol_HCP[i,j] = get_null_p(grayvol_HCP[:,i,j], np.median(null_grayvol_HCP[:,i,j]))
        p_grayvol_ABCD[i,j] = get_null_p(grayvol_ABCD[:,i,j], np.median(null_grayvol_ABCD[:,i,j]))
        
        p_thick_HCP[i,j] = get_null_p(thick_HCP[:,i,j], np.median(null_thick_HCP[:,i,j]))
        p_thick_ABCD[i,j] = get_null_p(thick_ABCD[:,i,j], np.median(null_thick_ABCD[:,i,j]))
        
        
        p_surfarea_norm_HCP[i,j] = get_null_p(surfarea_norm_HCP[:,i,j], np.median(null_surfarea_norm_HCP[:,i,j]))
        p_surfarea_norm_ABCD[i,j] = get_null_p(surfarea_norm_ABCD[:,i,j], np.median(null_surfarea_norm_ABCD[:,i,j]))
        
        p_grayvol_norm_HCP[i,j] = get_null_p(grayvol_norm_HCP[:,i,j], np.median(null_grayvol_norm_HCP[:,i,j]))
        p_grayvol_norm_ABCD[i,j] = get_null_p(grayvol_norm_ABCD[:,i,j], np.median(null_grayvol_norm_ABCD[:,i,j]))
        
        p_thick_norm_HCP[i,j] = get_null_p(thick_norm_HCP[:,i,j], np.median(null_thick_norm_HCP[:,i,j]))
        p_thick_norm_ABCD[i,j] = get_null_p(thick_norm_ABCD[:,i,j], np.median(null_thick_norm_ABCD[:,i,j]))
        
        
#get p values comparing true sex-specific models to null models
for i in range(n_cog):
    for j in range(test_ss):
        p_surfarea_HCP_m[i,j] = get_null_p(surfarea_HCP_m[:,i,j], np.median(null_surfarea_HCP_m[:,i,j]))
        p_surfarea_ABCD_m[i,j] = get_null_p(surfarea_ABCD_m[:,i,j], np.median(null_surfarea_ABCD_m[:,i,j]))
        
        p_grayvol_HCP_m[i,j] = get_null_p(grayvol_HCP_m[:,i,j], np.median(null_grayvol_HCP_m[:,i,j]))
        p_grayvol_ABCD_m[i,j] = get_null_p(grayvol_ABCD_m[:,i,j], np.median(null_grayvol_ABCD_m[:,i,j]))
        
        p_thick_HCP_m[i,j] = get_null_p(thick_HCP_m[:,i,j], np.median(null_thick_HCP_m[:,i,j]))
        p_thick_ABCD_m[i,j] = get_null_p(thick_ABCD_m[:,i,j], np.median(null_thick_ABCD_m[:,i,j]))
        
        
        p_surfarea_norm_HCP_m[i,j] = get_null_p(surfarea_norm_HCP_m[:,i,j], np.median(null_surfarea_norm_HCP_m[:,i,j]))
        p_surfarea_norm_ABCD_m[i,j] = get_null_p(surfarea_norm_ABCD_m[:,i,j], np.median(null_surfarea_norm_ABCD_m[:,i,j]))
        
        p_grayvol_norm_HCP_m[i,j] = get_null_p(grayvol_norm_HCP_m[:,i,j], np.median(null_grayvol_norm_HCP_m[:,i,j]))
        p_grayvol_norm_ABCD_m[i,j] = get_null_p(grayvol_norm_ABCD_m[:,i,j], np.median(null_grayvol_norm_ABCD_m[:,i,j]))
        
        p_thick_norm_HCP_m[i,j] = get_null_p(thick_norm_HCP_m[:,i,j], np.median(null_thick_norm_HCP_m[:,i,j]))
        p_thick_norm_ABCD_m[i,j] = get_null_p(thick_norm_ABCD_m[:,i,j], np.median(null_thick_norm_ABCD_m[:,i,j]))
        
        
        
        p_surfarea_HCP_f[i,j] = get_null_p(surfarea_HCP_f[:,i,j], np.median(null_surfarea_HCP_f[:,i,j]))
        p_surfarea_ABCD_f[i,j] = get_null_p(surfarea_ABCD_f[:,i,j], np.median(null_surfarea_ABCD_f[:,i,j]))
        
        p_grayvol_HCP_f[i,j] = get_null_p(grayvol_HCP_f[:,i,j], np.median(null_grayvol_HCP_f[:,i,j]))
        p_grayvol_ABCD_f[i,j] = get_null_p(grayvol_ABCD_f[:,i,j], np.median(null_grayvol_ABCD_f[:,i,j]))
        
        p_thick_HCP_f[i,j] = get_null_p(thick_HCP_f[:,i,j], np.median(null_thick_HCP_f[:,i,j]))
        p_thick_ABCD_f[i,j] = get_null_p(thick_ABCD_f[:,i,j], np.median(null_thick_ABCD_f[:,i,j]))
        
        
        p_surfarea_norm_HCP_f[i,j] = get_null_p(surfarea_norm_HCP_f[:,i,j], np.median(null_surfarea_norm_HCP_f[:,i,j]))
        p_surfarea_norm_ABCD_f[i,j] = get_null_p(surfarea_norm_ABCD_f[:,i,j], np.median(null_surfarea_norm_ABCD_f[:,i,j]))
        
        p_grayvol_norm_HCP_f[i,j] = get_null_p(grayvol_norm_HCP_f[:,i,j], np.median(null_grayvol_norm_HCP_f[:,i,j]))
        p_grayvol_norm_ABCD_f[i,j] = get_null_p(grayvol_norm_ABCD_f[:,i,j], np.median(null_grayvol_norm_ABCD_f[:,i,j]))
        
        p_thick_norm_HCP_f[i,j] = get_null_p(thick_norm_HCP_f[:,i,j], np.median(null_thick_norm_HCP_f[:,i,j]))
        p_thick_norm_ABCD_f[i,j] = get_null_p(thick_norm_ABCD_f[:,i,j], np.median(null_thick_norm_ABCD_f[:,i,j]))

# %%
#correct all p values fro multiple comparisons
for i in range(test_si):
    p_surfarea_HCP[:,i] = fdr(p_surfarea_HCP[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_surfarea_ABCD[:,i] = fdr(p_surfarea_ABCD[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]

    p_grayvol_HCP[:,i] = fdr(p_grayvol_HCP[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_grayvol_ABCD[:,i] = fdr(p_grayvol_ABCD[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    
    p_thick_HCP[:,i] = fdr(p_thick_HCP[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_thick_ABCD[:,i] = fdr(p_thick_ABCD[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    
    p_surfarea_norm_HCP[:,i] = fdr(p_surfarea_norm_HCP[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_surfarea_norm_ABCD[:,i] = fdr(p_surfarea_norm_ABCD[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]

    p_grayvol_norm_HCP[:,i] = fdr(p_grayvol_norm_HCP[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_grayvol_norm_ABCD[:,i] = fdr(p_grayvol_norm_ABCD[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    
    p_thick_norm_HCP[:,i] = fdr(p_thick_norm_HCP[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_thick_norm_ABCD[:,i] = fdr(p_thick_norm_ABCD[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    
    
for i in range(test_ss):
    p_surfarea_HCP_m[:,i] = fdr(p_surfarea_HCP_m[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_surfarea_ABCD_m[:,i] = fdr(p_surfarea_ABCD_m[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]

    p_grayvol_HCP_m[:,i] = fdr(p_grayvol_HCP_m[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_grayvol_ABCD_m[:,i] = fdr(p_grayvol_ABCD_m[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    
    p_thick_HCP_m[:,i] = fdr(p_thick_HCP_m[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_thick_ABCD_m[:,i] = fdr(p_thick_ABCD_m[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    
    p_surfarea_norm_HCP_m[:,i] = fdr(p_surfarea_norm_HCP_m[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_surfarea_norm_ABCD_m[:,i] = fdr(p_surfarea_norm_ABCD_m[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]

    p_grayvol_norm_HCP_m[:,i] = fdr(p_grayvol_norm_HCP_m[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_grayvol_norm_ABCD_m[:,i] = fdr(p_grayvol_norm_ABCD_m[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    
    p_thick_norm_HCP_m[:,i] = fdr(p_thick_norm_HCP_m[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_thick_norm_ABCD_m[:,i] = fdr(p_thick_norm_ABCD_m[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    
    
    p_surfarea_HCP_f[:,i] = fdr(p_surfarea_HCP_f[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_surfarea_ABCD_f[:,i] = fdr(p_surfarea_ABCD_f[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]

    p_grayvol_HCP_f[:,i] = fdr(p_grayvol_HCP_f[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_grayvol_ABCD_f[:,i] = fdr(p_grayvol_ABCD_f[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    
    p_thick_HCP_f[:,i] = fdr(p_thick_HCP_f[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_thick_ABCD_f[:,i] = fdr(p_thick_ABCD_f[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    
    p_surfarea_norm_HCP_f[:,i] = fdr(p_surfarea_norm_HCP_f[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_surfarea_norm_ABCD_f[:,i] = fdr(p_surfarea_norm_ABCD_f[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]

    p_grayvol_norm_HCP_f[:,i] = fdr(p_grayvol_norm_HCP_f[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_grayvol_norm_ABCD_f[:,i] = fdr(p_grayvol_norm_ABCD_f[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    
    p_thick_norm_HCP_f[:,i] = fdr(p_thick_norm_HCP_f[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
    p_thick_norm_ABCD_f[:,i] = fdr(p_thick_norm_ABCD_f[:,i], alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]

# %%
cog = ['Fluid Composite', 'Total Composite', 'Crystal Composite',
       'Visual Episodic Memory', 'Cognitive Flexibility (Card Sort)',
       'Inhibition (Flanker)', 'Reading Decoding', 'Vocabulary Comprehension', 
       'Processing Speed', 'Working Memory (List Sorting)']

reorder_cog = ['Total Composite', 'Crystal Composite', 'Reading Decoding', 'Vocabulary Comprehension', 
         'Fluid Composite', 'Visual Episodic Memory', 'Cognitive Flexibility (Card Sort)',
         'Inhibition (Flanker)', 'Processing Speed', 'Working Memory (List Sorting)']


test_si = ['HCP', 'ABCD']
test_ss = ['HCP - M' ,'HCP - F', 'ABCD - M', 'ABCD - F']

# %%
#create funciton to color tables based on p value threshold
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'black' if val > 0.05 else 'red'
    return 'color: %s' % color

# %%
#compare performance between pairs of models: with an without ICV norm
p_model_comp_surfarea_HCP = np.zeros([10])
p_model_comp_surfarea_HCP_m = np.zeros([10])
p_model_comp_surfarea_HCP_f = np.zeros([10])

p_model_comp_grayvol_HCP = np.zeros([10])
p_model_comp_grayvol_HCP_m = np.zeros([10])
p_model_comp_grayvol_HCP_f = np.zeros([10])

p_model_comp_thick_HCP = np.zeros([10])
p_model_comp_thick_HCP_m = np.zeros([10])
p_model_comp_thick_HCP_f = np.zeros([10])


p_model_comp_surfarea_ABCD = np.zeros([10])
p_model_comp_surfarea_ABCD_m = np.zeros([10])
p_model_comp_surfarea_ABCD_f = np.zeros([10])

p_model_comp_grayvol_ABCD = np.zeros([10])
p_model_comp_grayvol_ABCD_m = np.zeros([10])
p_model_comp_grayvol_ABCD_f = np.zeros([10])

p_model_comp_thick_ABCD = np.zeros([10])
p_model_comp_thick_ABCD_m = np.zeros([10])
p_model_comp_thick_ABCD_f = np.zeros([10])


for i in range(n_cog):
    
    p_model_comp_surfarea_HCP[i] = get_exact_p(surfarea_HCP[:,i,0], surfarea_norm_HCP[:,i,0])
    p_model_comp_surfarea_HCP_m[i] = get_exact_p(surfarea_HCP_m[:,i,0], surfarea_norm_HCP_m[:,i,0])
    p_model_comp_surfarea_HCP_f[i] = get_exact_p(surfarea_HCP_f[:,i,1], surfarea_norm_HCP_f[:,i,1])
    p_model_comp_surfarea_HCP[i] = get_exact_p(surfarea_ABCD[:,i,1], surfarea_norm_ABCD[:,i,1])
    p_model_comp_surfarea_ABCD_m[i] = get_exact_p(surfarea_ABCD_m[:,i,2], surfarea_norm_ABCD_m[:,i,2])
    p_model_comp_surfarea_ABCD_f[i] = get_exact_p(surfarea_ABCD_f[:,i,3], surfarea_norm_ABCD_f[:,i,3])
    
    p_model_comp_grayvol_HCP[i] = get_exact_p(grayvol_HCP[:,i,0], grayvol_norm_HCP[:,i,0])
    p_model_comp_grayvol_HCP_m[i] = get_exact_p(grayvol_HCP_m[:,i,0], grayvol_norm_HCP_m[:,i,0])
    p_model_comp_grayvol_HCP_f[i] = get_exact_p(grayvol_HCP_f[:,i,1], grayvol_norm_HCP_f[:,i,1])
    p_model_comp_grayvol_HCP[i] = get_exact_p(grayvol_ABCD[:,i,1], grayvol_norm_ABCD[:,i,1])
    p_model_comp_grayvol_ABCD_m[i] = get_exact_p(grayvol_ABCD_m[:,i,2], grayvol_norm_ABCD_m[:,i,2])
    p_model_comp_grayvol_ABCD_f[i] = get_exact_p(grayvol_ABCD_f[:,i,3], grayvol_norm_ABCD_f[:,i,3])
    
    p_model_comp_thick_HCP[i] = get_exact_p(thick_HCP[:,i,0], thick_norm_HCP[:,i,0])
    p_model_comp_thick_HCP_m[i] = get_exact_p(thick_HCP_m[:,i,0], thick_norm_HCP_m[:,i,0])
    p_model_comp_thick_HCP_f[i] = get_exact_p(thick_HCP_f[:,i,1], thick_norm_HCP_f[:,i,1])
    p_model_comp_thick_HCP[i] = get_exact_p(thick_ABCD[:,i,1], thick_norm_ABCD[:,i,1])
    p_model_comp_thick_ABCD_m[i] = get_exact_p(thick_ABCD_m[:,i,2], thick_norm_ABCD_m[:,i,2])
    p_model_comp_thick_ABCD_f[i] = get_exact_p(thick_ABCD_f[:,i,3], thick_norm_ABCD_f[:,i,3])
    
    
        
#correct p values for multiple comparisons
p_corr_surfarea_HCP = fdr(p_model_comp_surfarea_HCP, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
p_corr_surfarea_HCP_m = fdr(p_model_comp_surfarea_HCP_m, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
p_corr_surfarea_HCP_f = fdr(p_model_comp_surfarea_HCP_f, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]

p_corr_surfarea_ABCD = fdr(p_model_comp_surfarea_ABCD, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
p_corr_surfarea_ABCD_m = fdr(p_model_comp_surfarea_ABCD_m, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
p_corr_surfarea_ABCD_f = fdr(p_model_comp_surfarea_ABCD_f, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]

p_corr_grayvol_HCP = fdr(p_model_comp_grayvol_HCP, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
p_corr_grayvol_HCP_m = fdr(p_model_comp_grayvol_HCP_m, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
p_corr_grayvol_HCP_f = fdr(p_model_comp_grayvol_HCP_f, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]

p_corr_grayvol_ABCD = fdr(p_model_comp_grayvol_ABCD, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
p_corr_grayvol_ABCD_m = fdr(p_model_comp_grayvol_ABCD_m, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
p_corr_grayvol_ABCD_f = fdr(p_model_comp_grayvol_ABCD_f, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]

p_corr_thick_HCP = fdr(p_model_comp_thick_HCP, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
p_corr_thick_HCP_m = fdr(p_model_comp_thick_HCP_m, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
p_corr_thick_HCP_f = fdr(p_model_comp_thick_HCP_f, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]

p_corr_thick_ABCD = fdr(p_model_comp_thick_ABCD, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
p_corr_thick_ABCD_m = fdr(p_model_comp_thick_ABCD_m, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]
p_corr_thick_ABCD_f = fdr(p_model_comp_thick_ABCD_f, alpha=0.05, method='fdr_bh', is_sorted=False, returnsorted=False)[1]

# %%
df = pd.DataFrame(p_corr_surfarea_ABCD_m, index=cog)
df = df.style.applymap(color_negative_red)
df
